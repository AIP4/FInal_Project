# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath("../"))

from utils import *

# Load dataset
region="seoul"
path = f"../../collect_data/filtered/kma/merged/kma_{region}_meta.csv"

# 2. CSV 파일 읽어서 데이터프레임으로 변환
korea_data = pd.read_csv(path)
china_data = concat_china_data(korea_data)

korea_data = convert_timesteps(korea_data)
print_missing_info(korea_data)

china_data = convert_timesteps(china_data)
print_missing_info(china_data)
# Out:
# (40175, 26)
# Series([], dtype: float64)
# Index(['TM', 'STN', 'WD', 'WS', 'PA', 'PS', 'TA', 'TD', 'HM', 'PV', 'WW',
#        'CA_TOT', 'CA_MID', 'CT', 'VS', 'TS', 'TE_005', 'TE_01', 'TE_02',
#        'TE_03', 'IR', 'PM10', '지점', '위도', '경도', 'diff'],
#       dtype='object')
# (9488, 111)
# VV             0.031619
# WD_yanan       0.021079
# WS_yanan       0.021079
# TA_yanan       0.105396
# TD_yanan       0.274030
# HM_yanan       0.685076
# PS_yanan       0.031619
# PR             0.063238
# VV_tongliao    0.010540
# WD_tongliao    0.010540
# WS_tongliao    0.010540
# TA_tongliao    0.137015
# TD_tongliao    0.252951
# HM_tongliao    0.242411
# PS_tongliao    0.010540
# PR_tongliao    0.010540
# VV_qingdao     0.094857
# WD_qingdao     0.115936
# WS_qingdao     0.115936
# TA_qingdao     0.094857
# TD_qingdao     0.200253
# HM_qingdao     0.790472
# PS_qingdao     0.094857
# PR_qingdao     0.094857
# VV_chifeng     0.063238
# WD_chifeng     0.021079
# WS_chifeng     0.063238
# TA_chifeng     0.115936
# TD_chifeng     0.263491
# HM_chifeng     0.179174
# PS_chifeng     0.031619
# PR_chifeng     0.021079
# TA_dalian      0.042159
# TD_dalian      0.242411
# HM_dalian      0.042159
# dtype: float64
# Index(['TM', 'STN', 'WD', 'WS', 'PA', 'PS', 'TA', 'TD', 'HM', 'PV',
#        ...
#        'TD_dalian', 'HM_dalian', 'PS_dalian', 'PT_dalian', 'PR_dalian',
#        'RH_dalian', 'PM10_dalian', 'LON_dalian', 'LAT_dalian', 'diff'],
#       dtype='object', length=111)

# %% [markdown]
# ## 한국만
# feature importance 상위 10개

# %%
"""import tensorflow as tf
import numpy as np
from permutation import permutation
from MLP import train_and_evaluate

selected_column=['TE_005','VS','TE_02','HM','TA','PS','TD','TE_01','TS','IR']

# Features (X) and target (y)
X = korea_data[selected_column]

# 결측값 처리하는 세가지 방안
#X.fillna(0, inplace=True)
X = X.fillna(X.mean())
#X.fillna(X.median(), inplace=True)

y = korea_data['PM10']

# Train the model and get the necessary data
mean_mae, test_mae, trained_model, X_train_val, y_train_val, X_test, y_test = train_and_evaluate(
    X, y, test_size=0.2, n_splits=5, epochs=100, batch_size=64
)

# Evaluate the model and calculate permutation importance
mean_mae, low_importance_features, features_with_scores = permutation(
    trained_model, X_train_val, y_train_val, X_test, y_test
)

# Print the low importance features and their scores
print(f"Low Importance Features: {low_importance_features}")
print(f"Features with Importance Scores: {features_with_scores}")"""
# Out:
# Cross-validated Mean Absolute Error: 21.146076965332032
# 252/252 [==============================] - 0s 1ms/step - loss: 557.9089 - mae: 16.8287
# Test Set Mean Absolute Error: 16.828699111938477
# Model Evaluation - Mean Absolute Error: 15618.453125
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 974us/step
# 252/252 [==============================] - 0s 984us/step
# 252/252 [==============================] - 0s 991us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 970us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 993us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 949us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 911us/step
# 252/252 [==============================] - 0s 924us/step
# 252/252 [==============================] - 0s 905us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 934us/step
# 252/252 [==============================] - 0s 667us/step
# 252/252 [==============================] - 0s 899us/step
# 252/252 [==============================] - 0s 942us/step
# 252/252 [==============================] - 0s 928us/step
# 252/252 [==============================] - 0s 916us/step
# 252/252 [==============================] - 0s 914us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 948us/step
# 252/252 [==============================] - 0s 981us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 982us/step
# 252/252 [==============================] - 0s 975us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 1s 1ms/step
# 252/252 [==============================] - 0s 959us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 859us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 946us/step
# 252/252 [==============================] - 0s 942us/step
# 252/252 [==============================] - 0s 953us/step
# 252/252 [==============================] - 0s 958us/step
# 252/252 [==============================] - 0s 950us/step
# 252/252 [==============================] - 0s 912us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 961us/step
# 252/252 [==============================] - 0s 955us/step
# 252/252 [==============================] - 0s 630us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 975us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 958us/step
# 252/252 [==============================] - 0s 954us/step
# 252/252 [==============================] - 0s 957us/step
# 252/252 [==============================] - 0s 1ms/step
# 252/252 [==============================] - 0s 966us/step
# 252/252 [==============================] - 0s 946us/step
# 252/252 [==============================] - 0s 1ms/step
# Feature: TE_005, Importance: 7.289712848413546
# Feature: VS, Importance: 374.6312953379849
# Feature: TE_02, Importance: 0.07030262355438026
# Feature: HM, Importance: 29.471793919030098
# Feature: TA, Importance: 2.1615748211479513
# Feature: PS, Importance: 374.66541026472044
# Feature: TD, Importance: -1.4621457608674973
# Feature: TE_01, Importance: -0.3110213926189317
# Feature: TS, Importance: -3.010735029643547
# Feature: IR, Importance: 0.023905231686148908
# Low Importance Features: ['TD', 'TE_01', 'TS']
# Features with Importance Scores: [('TE_005', 7.289712848413546), ('VS', 374.6312953379849), ('TE_02', 0.07030262355438026), ('HM', 29.471793919030098), ('TA', 2.1615748211479513), ('PS', 374.66541026472044), ('TD', -1.4621457608674973), ('TE_01', -0.3110213926189317), ('TS', -3.010735029643547), ('IR', 0.023905231686148908)]

# %% [markdown]
# ## 한국 & 중국
# feature importance 상위 10개

# %%
import tensorflow as tf
import numpy as np
from permutation import permutation
from MLP import train_and_evaluate

selected_column=['VS','PA','PS','TE_005','TA','WD_qingdao','PS_dalian','WD_yanan','HM_tongliao','PV']

# Features (X) and target (y)
X = china_data[selected_column]

# 결측값 처리하는 세가지 방안
#X.fillna(0, inplace=True)
X = X.fillna(X.mean())
#X.fillna(X.median(), inplace=True)

y = china_data['PM10']

# Step 1: Train the model and get the necessary data
mean_mae, test_mae, trained_model, X_train_val, y_train_val, X_test, y_test = train_and_evaluate(
    X, y, test_size=0.2, n_splits=5, epochs=100, batch_size=64
)

# Step 2: Evaluate the model and calculate permutation importance
mean_mae, low_importance_features, features_with_scores = permutation(
    trained_model, X_train_val, y_train_val, X_test, y_test
)

# Print the low importance features and their scores
print(f"Low Importance Features: {low_importance_features}")
print(f"Features with Importance Scores: {features_with_scores}")
# Out:
# Cross-validated Mean Absolute Error: 24.791265106201173
# 60/60 [==============================] - 0s 1ms/step - loss: 595.0041 - mae: 17.0815
# Test Set Mean Absolute Error: 17.081514358520508
# Model Evaluation - Mean Absolute Error: 17863.29296875
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 820us/step
# 60/60 [==============================] - 0s 942us/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 458us/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# Feature: PS_dalian, Importance: 2.084031015558139
# Feature: TE_005, Importance: -2.02858748039107
# Feature: HM, Importance: -2.1318814036032565
# Feature: VS, Importance: 261.57863903947475
# Feature: PS_qingdao, Importance: -1.2975370473566727
# Feature: PV, Importance: 0.2013459144061926
# Feature: TA_dalian, Importance: 0.052899512399017114
# Feature: TA, Importance: 0.08131456445335061
# Feature: PS_chifeng, Importance: -0.3791286512732768
# Feature: PA, Importance: 266.9758309591991
# Low Importance Features: ['TE_005', 'HM', 'PS_qingdao', 'PS_chifeng']
# Features with Importance Scores: [('PS_dalian', 2.084031015558139), ('TE_005', -2.02858748039107), ('HM', -2.1318814036032565), ('VS', 261.57863903947475), ('PS_qingdao', -1.2975370473566727), ('PV', 0.2013459144061926), ('TA_dalian', 0.052899512399017114), ('TA', 0.08131456445335061), ('PS_chifeng', -0.3791286512732768), ('PA', 266.9758309591991)]
